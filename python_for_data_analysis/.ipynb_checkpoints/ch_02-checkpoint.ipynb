# %% [markdown]
# # 第二章

# %% [markdown]
# ### 来自bit.ly的1.usa.gov数据

# %%
path = "/Users/xinyu/Documents/JupyterNotebook/Python_for_Data_Analysis/ch02/usagov_bitly_data2012-03-16-1331923249.txt"

# %%
open(path).readline()
# Out:
# '{ "a": "Mozilla\\/5.0 (Windows NT 6.1; WOW64) AppleWebKit\\/535.11 (KHTML, like Gecko) Chrome\\/17.0.963.78 Safari\\/535.11", "c": "US", "nk": 1, "tz": "America\\/New_York", "gr": "MA", "g": "A6qOVH", "h": "wfLQtf", "l": "orofrog", "al": "en-US,en;q=0.8", "hh": "1.usa.gov", "r": "http:\\/\\/www.facebook.com\\/l\\/7AQEFzjSi\\/1.usa.gov\\/wfLQtf", "u": "http:\\/\\/www.ncbi.nlm.nih.gov\\/pubmed\\/22415991", "t": 1331923247, "hc": 1331822918, "cy": "Danvers", "ll": [ 42.576698, -70.954903 ] }\n'

# %%
import json
path = "ch02/usagov_bitly_data2012-03-16-1331923249.txt"
records = [json.loads(line) for line in open(path)]

# %%
records[0]
# Out:
# {'a': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.78 Safari/535.11',
#  'c': 'US',
#  'nk': 1,
#  'tz': 'America/New_York',
#  'gr': 'MA',
#  'g': 'A6qOVH',
#  'h': 'wfLQtf',
#  'l': 'orofrog',
#  'al': 'en-US,en;q=0.8',
#  'hh': '1.usa.gov',
#  'r': 'http://www.facebook.com/l/7AQEFzjSi/1.usa.gov/wfLQtf',
#  'u': 'http://www.ncbi.nlm.nih.gov/pubmed/22415991',
#  't': 1331923247,
#  'hc': 1331822918,
#  'cy': 'Danvers',
#  'll': [42.576698, -70.954903]}

# %%
records[0]['tz']
# Out:
# 'America/New_York'

# %% [markdown]
# ### 用纯python 代码对时区进行计数

# %%
time_zones = [rec['tz'] for rec in records if 'tz' in rec]

# %%
time_zones[:10]
# Out:
# ['America/New_York',
#  'America/Denver',
#  'America/New_York',
#  'America/Sao_Paulo',
#  'America/New_York',
#  'America/New_York',
#  'Europe/Warsaw',
#  '',
#  '',
#  '']

# %%
def get_counts(sequence):
    counts = {}
    for x in sequence:
        if x in counts:
            counts[x] += 1
        else:
            counts[x] = 1
    return counts

# %%
counts = get_counts(time_zones)

# %%
counts["America/New_York"]
# Out:
# 1251

# %%
len(time_zones)
# Out:
# 3440

# %%
def top_counts(count_dict,n=10):
    value_key_pairs = [(count, tz) for tz, count in count_dict.items()]
    value_key_pairs.sort()
    return value_key_pairs[-n:]

# %%
top_counts(counts)
# Out:
# [(33, 'America/Sao_Paulo'),
#  (35, 'Europe/Madrid'),
#  (36, 'Pacific/Honolulu'),
#  (37, 'Asia/Tokyo'),
#  (74, 'Europe/London'),
#  (191, 'America/Denver'),
#  (382, 'America/Los_Angeles'),
#  (400, 'America/Chicago'),
#  (521, ''),
#  (1251, 'America/New_York')]

# %%
from collections import Counter

# %%
counts = Counter(time_zones)

# %%
counts.most_common(10)
# Out:
# [('America/New_York', 1251),
#  ('', 521),
#  ('America/Chicago', 400),
#  ('America/Los_Angeles', 382),
#  ('America/Denver', 191),
#  ('Europe/London', 74),
#  ('Asia/Tokyo', 37),
#  ('Pacific/Honolulu', 36),
#  ('Europe/Madrid', 35),
#  ('America/Sao_Paulo', 33)]

# %% [markdown]
# ### 用pandas对时区进行计数

# %%
from pandas import DataFrame,Series
import pandas as pd
import numpy as np

# %%
frame  = DataFrame(records)

# %%
frame
# Out:
#        _heartbeat_                        ...                                                                          u
# 0              NaN                        ...                                http://www.ncbi.nlm.nih.gov/pubmed/22415991
# 1              NaN                        ...                                http://www.monroecounty.gov/etc/911/rss.php
# 2              NaN                        ...                          http://boxer.senate.gov/en/press/releases/0316...
# 3              NaN                        ...                                    http://apod.nasa.gov/apod/ap120312.html
# 4              NaN                        ...                          http://www.shrewsbury-ma.gov/egov/gallery/1341...
# 5              NaN                        ...                          http://www.shrewsbury-ma.gov/egov/gallery/1341...
# 6              NaN                        ...                          http://www.nasa.gov/mission_pages/nustar/main/...
# 7              NaN                        ...                          http://www.nasa.gov/mission_pages/nustar/main/...
# 8              NaN                        ...                          http://www.nasa.gov/mission_pages/nustar/main/...
# 9              NaN                        ...                                    http://apod.nasa.gov/apod/ap120312.html
# 10             NaN                        ...                          https://www.nysdot.gov/rexdesign/design/commun...
# 11             NaN                        ...                          http://oversight.house.gov/wp-content/uploads/...
# 12             NaN                        ...                          https://www.nysdot.gov/rexdesign/design/commun...
# 13    1.331923e+09                        ...                                                                        NaN
# 14             NaN                        ...                                       http://toxtown.nlm.nih.gov/index.php
# 15             NaN                        ...                          http://www.ssd.noaa.gov/PS/TROP/TCFP/data/curr...
# 16             NaN                        ...                          http://www.usno.navy.mil/NOOC/nmfc-ph/RSS/jtwc...
# 17             NaN                        ...                          http://www.usda.gov/wps/portal/usda/usdahome?c...
# 18             NaN                        ...                                http://www.monroecounty.gov/etc/911/rss.php
# 19             NaN                        ...                          http://www.nasa.gov/mission_pages/nustar/main/...
# 20             NaN                        ...                          http://voyager.jpl.nasa.gov/imagesvideo/uranus...
# 21             NaN                        ...                          http://www.nasa.gov/mission_pages/nustar/main/...
# 22             NaN                        ...                          http://portal.hud.gov/hudportal/documents/hudd...
# 23             NaN                        ...                          http://www.tricare.mil/mybenefit/ProfileFilter...
# 24             NaN                        ...                          http://www.nasa.gov/mission_pages/nustar/main/...
# 25             NaN                        ...                          http://www.nasa.gov/mission_pages/nustar/main/...
# 26             NaN                        ...                          http://www.nasa.gov/mission_pages/nustar/main/...
# 27             NaN                        ...                                    http://apod.nasa.gov/apod/ap120312.html
# 28             NaN                        ...                          https://www.nysdot.gov/rexdesign/design/commun...
# 29             NaN                        ...                          http://www.ed.gov/news/media-advisories/us-dep...
# ...            ...                        ...                                                                        ...
# 3530           NaN                        ...                          http://www.nasa.gov/multimedia/imagegallery/im...
# 3531           NaN                        ...                          http://www.nasa.gov/mission_pages/nustar/main/...
# 3532           NaN                        ...                          http://portal.hud.gov/hudportal/HUD?src=/press...
# 3533           NaN                        ...                                                 http://apod.nasa.gov/apod/
# 3534           NaN                        ...                          https://www.nysdot.gov/rexdesign/design/commun...
# 3535           NaN                        ...                          http://ntl.bts.gov/lib/44000/44300/44374/FHWA-...
# 3536           NaN                        ...                          http://www.nasa.gov/mission_pages/hurricanes/a...
# 3537           NaN                        ...                                    http://apod.nasa.gov/apod/ap120312.html
# 3538           NaN                        ...                          http://healthypeople.gov/2020/connect/webinars...
# 3539           NaN                        ...                          http://www.federalreserve.gov/newsevents/press...
# 3540           NaN                        ...                          http://www.nasa.gov/mission_pages/nustar/main/...
# 3541           NaN                        ...                          http://www.federalreserve.gov/newsevents/press...
# 3542           NaN                        ...                          http://www.sba.gov/community/blogs/community-b...
# 3543  1.331927e+09                        ...                                                                        NaN
# 3544           NaN                        ...                          https://www.nysdot.gov/rexdesign/design/commun...
# 3545           NaN                        ...                          https://www.nysdot.gov/rexdesign/design/commun...
# 3546           NaN                        ...                          http://healthypeople.gov/2020/connect/webinars...
# 3547           NaN                        ...                          http://www.epa.gov/otaq/regs/fuels/additive/e1...
# 3548           NaN                        ...                            http://www.fda.gov/Safety/Recalls/ucm296326.htm
# 3549           NaN                        ...                          http://www.nasa.gov/mission_pages/WISE/main/in...
# 3550           NaN                        ...                          http://www.nlm.nih.gov/medlineplus/news/fullst...
# 3551           NaN                        ...                          http://www.nasa.gov/mission_pages/nustar/main/...
# 3552           NaN                        ...                          http://travel.state.gov/passport/passport_5535...
# 3553           NaN                        ...                          http://www.shrewsbury-ma.gov/egov/gallery/1341...
# 3554           NaN                        ...                          http://www.shrewsbury-ma.gov/egov/gallery/1341...
# 3555           NaN                        ...                          http://www.fda.gov/AdvisoryCommittees/Committe...
# 3556           NaN                        ...                          http://www.okc.gov/PublicNotificationSystem/Fo...
# 3557           NaN                        ...                                http://www.monroecounty.gov/etc/911/rss.php
# 3558           NaN                        ...                                        http://www.ahrq.gov/qual/qitoolkit/
# 3559           NaN                        ...                          http://herndon-va.gov/Content/public_safety/Pu...
#
# [3560 rows x 18 columns]

# %%
frame['tz'][:10]
# Out:
# 0     America/New_York
# 1       America/Denver
# 2     America/New_York
# 3    America/Sao_Paulo
# 4     America/New_York
# 5     America/New_York
# 6        Europe/Warsaw
# 7
# 8
# 9
# Name: tz, dtype: object

# %%
tz_counts = frame['tz'].value_counts()

# %%
tz_counts[:10]
# Out:
# America/New_York       1251
#                         521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# America/Sao_Paulo        33
# Name: tz, dtype: int64

# %%
clean_tz = frame['tz'].fillna('Missing')
clean_tz[clean_tz == ''] = 'Unknown'
tz_counts = clean_tz.value_counts()

# %%
tz_counts[:10]
# Out:
# America/New_York       1251
# Unknown                 521
# America/Chicago         400
# America/Los_Angeles     382
# America/Denver          191
# Missing                 120
# Europe/London            74
# Asia/Tokyo               37
# Pacific/Honolulu         36
# Europe/Madrid            35
# Name: tz, dtype: int64

# %%
tz_counts[:10].plot(kind='barh',rot=0)

# %%
frame['a'][1]
# Out:
# 'GoogleMaps/RochesterNY'

# %%
frame['a'][50]
# Out:
# 'Mozilla/5.0 (Windows NT 5.1; rv:10.0.2) Gecko/20100101 Firefox/10.0.2'

# %%
frame['a'][51]
# Out:
# 'Mozilla/5.0 (Linux; U; Android 2.2.2; en-us; LG-P925/V10e Build/FRG83G) AppleWebKit/533.1 (KHTML, like Gecko) Version/4.0 Mobile Safari/533.1'

# %%
results = Series([x.split()[0]] for x in frame.a.dropna())

# %%
results[:5]
# Out:
# 0               [Mozilla/5.0]
# 1    [GoogleMaps/RochesterNY]
# 2               [Mozilla/4.0]
# 3               [Mozilla/5.0]
# 4               [Mozilla/5.0]
# dtype: object

# %%
#results.value_counts()[:8]

# %% [markdown]
# ### MovieLens 1M 数据集

# %%
import pandas as pd
unames = ['user_id','gender','age','occupation','zip']
users = pd.read_table('ch02/movielens/users.dat',sep='::',header=None,names=unames)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
rnames = ['user_id','movie_id','rating','timestamp']
ratings = pd.read_table('ch02/movielens/ratings.dat',sep='::',header=None,names=rnames)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
mnames = ['movie_id','title','genres']
movies = pd.read_table('ch02/movielens/movies.dat',sep='::',header=None,names=mnames)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
users[:5]
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455

# %%
ratings[:5]
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
movies[:5]
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
data = pd.merge(pd.merge(ratings,users),movies)

# %%
data
# Out:
#          user_id           ...                            genres
# 0              1           ...                             Drama
# 1              2           ...                             Drama
# 2             12           ...                             Drama
# 3             15           ...                             Drama
# 4             17           ...                             Drama
# 5             18           ...                             Drama
# 6             19           ...                             Drama
# 7             24           ...                             Drama
# 8             28           ...                             Drama
# 9             33           ...                             Drama
# 10            39           ...                             Drama
# 11            42           ...                             Drama
# 12            44           ...                             Drama
# 13            47           ...                             Drama
# 14            48           ...                             Drama
# 15            49           ...                             Drama
# 16            53           ...                             Drama
# 17            54           ...                             Drama
# 18            58           ...                             Drama
# 19            59           ...                             Drama
# 20            62           ...                             Drama
# 21            80           ...                             Drama
# 22            81           ...                             Drama
# 23            88           ...                             Drama
# 24            89           ...                             Drama
# 25            95           ...                             Drama
# 26            96           ...                             Drama
# 27            99           ...                             Drama
# 28           102           ...                             Drama
# 29           104           ...                             Drama
# ...          ...           ...                               ...
# 1000179     4933           ...                       Documentary
# 1000180     4802           ...                             Drama
# 1000181     4812           ...                      Action|Crime
# 1000182     4874           ...             Action|Drama|Thriller
# 1000183     5059           ...                            Action
# 1000184     5947           ...                            Action
# 1000185     5077           ...                         Drama|War
# 1000186     5944           ...                         Drama|War
# 1000187     5105           ...                       Documentary
# 1000188     5185           ...                       Documentary
# 1000189     5532           ...                       Documentary
# 1000190     5543           ...                       Documentary
# 1000191     5220           ...                            Comedy
# 1000192     5754           ...                            Comedy
# 1000193     5227           ...             Action|Drama|Thriller
# 1000194     5795           ...             Action|Drama|Thriller
# 1000195     5313           ...                             Crime
# 1000196     5328           ...                    Drama|Thriller
# 1000197     5334           ...                      Comedy|Crime
# 1000198     5334           ...                             Drama
# 1000199     5334           ...                             Drama
# 1000200     5420           ...                 Children's|Comedy
# 1000201     5433           ...            Action|Sci-Fi|Thriller
# 1000202     5494           ...                            Comedy
# 1000203     5556           ...                       Documentary
# 1000204     5949           ...                       Documentary
# 1000205     5675           ...                             Drama
# 1000206     5780           ...                             Drama
# 1000207     5851           ...              Comedy|Drama|Western
# 1000208     5938           ...                       Documentary
#
# [1000209 rows x 10 columns]

# %%
data.ix[0]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# user_id                                            1
# movie_id                                        1193
# rating                                             5
# timestamp                                  978300760
# gender                                             F
# age                                                1
# occupation                                        10
# zip                                            48067
# title         One Flew Over the Cuckoo's Nest (1975)
# genres                                         Drama
# Name: 0, dtype: object

# %%
mean_ratings = data.pivot_table('rating',rows='title',cols='gender',aggfunc='mean')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-176-419e378de1c2> in <module>()
# ----> 1 mean_ratings = data.pivot_table('rating',rows='title',cols='gender',aggfunc='mean')
#
# TypeError: pivot_table() got an unexpected keyword argument 'rows'
