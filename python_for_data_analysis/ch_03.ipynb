# %% [markdown]
# # 第3章

# %% [markdown]
# ### Ipython 基础

# %%
from numpy.random import randn
import numpy as np
data = {i : randn() for i in range(7)}

# %%
data
# Out:
# {0: 1.4118519688938598,
#  1: 0.3932942030361781,
#  2: -0.22550787543522846,
#  3: -1.0434394199945523,
#  4: -0.1577086523041511,
#  5: -1.4168041384195473,
#  6: -1.1117507113636846}

# %%
print(data)
# Out:
# {0: 1.4118519688938598, 1: 0.3932942030361781, 2: -0.22550787543522846, 3: -1.0434394199945523, 4: -0.1577086523041511, 5: -1.4168041384195473, 6: -1.1117507113636846}

# %%
type(data)
# Out:
# dict

# %% [markdown]
# ### Tab 键自动补全

# %% [markdown]
# ### 内省

# %%
b=[1,2,3]

# %%
b?

# %%
def add_number(a,b):
    return a+b

# %%
add_number?

# %%
add_number??

# %%
np.*load*?

# %% [markdown]
# ### %run + 文件名

# %%
# %run ipython_script_test.py
# Out:
# ERROR:root:File `'ipython_script_test.py'` not found.

# %%
result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-0ac921c19f1a> in <module>()
# ----> 1 result
#
# NameError: name 'result' is not defined

# %%
c

# %% [markdown]
# ### 异常和跟踪

# %%
# %run ch03/ipython_bug.py

# %% [markdown]
# ### 魔术命令

# %%
a = np.random.randn(100,100)

# %%
a

# %%
# %timeit np.dot(a,a)

# %%
# %reset?

# %%
# %magic

# %%
ls

# %%
pwd

# %%
magic

# %%
quickref

# %% [markdown]
# ### matplotlib集成与pylab模式

# %%
ipython --pylab
img = plt.imread('ch03/stinkbug.png')

# %% [markdown]
# ### 交互式调试器

# %%
run ch03/ipython_bug.py

# %%
debug

# %%
run -d ch03/ipython_bug.py

# %% [markdown]
# ### 测试代码的执行时间：%time和%timeit

# %%
strings = ['foo','foobar','baz','qux','python','Guido Van Rossum'] * 100000

# %%
# %time method1 = [x for x in strings if x.startswith('foo')]

# %%
# %time method2 = [x for x in strings if x[:3] == 'foo']

# %%
# %timeit method1 = [x for x in strings if x.startswith('foo')]

# %%
# %timeit method2 = [x for x in strings if x[:3] == 'foo']

# %%
ls

# %%
ls ipython_example

# %%
ls

# %%
import numpy as np
import pandas as pd
print('hello world!')

# %%
tips = pd.read_csv('ch08/tips.csv')
tips.head()

# %%
import matplotlib.pyplot as plt # plt 用于显示图片
import matplotlib.image as mpimg # mpimg 用于读取图片
img = plt.imread('ch03/stinkbug.png')

# %%
img = plt.imread('ch03/stinkbug.png')

# %%
plt.imshow(img)
